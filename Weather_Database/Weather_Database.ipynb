# %% [markdown]
# # Deliverable 1 Retrieve Weather Data

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy  import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-140.000, high=140.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 762

# %%
#Print last city
print(city)
# Out:
# hermanus

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9d822535a4aff6e3f3ae17e65e288f54

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description" : city_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | arraial do cabo
# Processing Record 2 of Set 1 | karauzyak
# City not found. Skipping...
# Processing Record 3 of Set 1 | hithadhoo
# Processing Record 4 of Set 1 | menongue
# Processing Record 5 of Set 1 | dingle
# Processing Record 6 of Set 1 | cape town
# Processing Record 7 of Set 1 | rafai
# Processing Record 8 of Set 1 | georgiyevskoye
# Processing Record 9 of Set 1 | victoria
# Processing Record 10 of Set 1 | punta arenas
# Processing Record 11 of Set 1 | ovalle
# Processing Record 12 of Set 1 | hermanus
# Processing Record 13 of Set 1 | mago
# Processing Record 14 of Set 1 | longyearbyen
# Processing Record 15 of Set 1 | aberdeen
# Processing Record 16 of Set 1 | clyde river
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | washington
# Processing Record 19 of Set 1 | vila do maio
# Processing Record 20 of Set 1 | utete
# Processing Record 21 of Set 1 | saint anthony
# Processing Record 22 of Set 1 | barbar
# City not found. Skipping...
# Processing Record 23 of Set 1 | new norfolk
# Processing Record 24 of Set 1 | yulara
# Processing Record 25 of Set 1 | mahibadhoo
# Processing Record 26 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 27 of Set 1 | lagoa
# Processing Record 28 of Set 1 | lebu
# Processing Record 29 of Set 1 | port elizabeth
# Processing Record 30 of Set 1 | trinidad
# Processing Record 31 of Set 1 | busselton
# Processing Record 32 of Set 1 | zhigansk
# Processing Record 33 of Set 1 | rikitea
# Processing Record 34 of Set 1 | norman wells
# Processing Record 35 of Set 1 | warqla
# City not found. Skipping...
# Processing Record 36 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 37 of Set 1 | codrington
# Processing Record 38 of Set 1 | buon me thuot
# City not found. Skipping...
# Processing Record 39 of Set 1 | maghama
# City not found. Skipping...
# Processing Record 40 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 41 of Set 1 | aksarka
# Processing Record 42 of Set 1 | ca mau
# Processing Record 43 of Set 1 | upernavik
# Processing Record 44 of Set 1 | upata
# Processing Record 45 of Set 1 | touros
# Processing Record 46 of Set 1 | torbay
# Processing Record 47 of Set 1 | malko tarnovo
# Processing Record 48 of Set 1 | atuona
# Processing Record 49 of Set 1 | bredasdorp
# Processing Record 50 of Set 1 | chicama
# Processing Record 1 of Set 2 | thompson
# Processing Record 2 of Set 2 | tanjong sepat
# City not found. Skipping...
# Processing Record 3 of Set 2 | teguise
# Processing Record 4 of Set 2 | yellowknife
# Processing Record 5 of Set 2 | vikhorevka
# Processing Record 6 of Set 2 | aklavik
# Processing Record 7 of Set 2 | vung tau
# Processing Record 8 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 9 of Set 2 | rorvik
# Processing Record 10 of Set 2 | tuktoyaktuk
# Processing Record 11 of Set 2 | port blair
# Processing Record 12 of Set 2 | aranjuez
# Processing Record 13 of Set 2 | mufulira
# Processing Record 14 of Set 2 | vestmannaeyjar
# Processing Record 15 of Set 2 | tiksi
# Processing Record 16 of Set 2 | cayenne
# Processing Record 17 of Set 2 | ardesen
# Processing Record 18 of Set 2 | ilulissat
# Processing Record 19 of Set 2 | goderich
# Processing Record 20 of Set 2 | rabo de peixe
# Processing Record 21 of Set 2 | coromandel
# Processing Record 22 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 23 of Set 2 | ribeira grande
# Processing Record 24 of Set 2 | trairi
# Processing Record 25 of Set 2 | bubaque
# Processing Record 26 of Set 2 | valparaiso
# Processing Record 27 of Set 2 | skibbereen
# Processing Record 28 of Set 2 | afonso claudio
# Processing Record 29 of Set 2 | troitskoye
# Processing Record 30 of Set 2 | ampanihy
# Processing Record 31 of Set 2 | carnarvon
# Processing Record 32 of Set 2 | jamestown
# Processing Record 33 of Set 2 | port augusta
# Processing Record 34 of Set 2 | tasiilaq
# Processing Record 35 of Set 2 | castro
# Processing Record 36 of Set 2 | cabo san lucas
# Processing Record 37 of Set 2 | bargal
# City not found. Skipping...
# Processing Record 38 of Set 2 | severnyy
# Processing Record 39 of Set 2 | albany
# Processing Record 40 of Set 2 | chuy
# Processing Record 41 of Set 2 | rocha
# Processing Record 42 of Set 2 | chegutu
# Processing Record 43 of Set 2 | dobre miasto
# Processing Record 44 of Set 2 | sochi
# Processing Record 45 of Set 2 | grand gaube
# Processing Record 46 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 47 of Set 2 | boa vista
# Processing Record 48 of Set 2 | rawah
# Processing Record 49 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 50 of Set 2 | boden
# Processing Record 1 of Set 3 | leirvik
# Processing Record 2 of Set 3 | ponta do sol
# Processing Record 3 of Set 3 | chimoio
# Processing Record 4 of Set 3 | prachuap khiri khan
# Processing Record 5 of Set 3 | pacific grove
# Processing Record 6 of Set 3 | mount isa
# Processing Record 7 of Set 3 | inhambane
# Processing Record 8 of Set 3 | caceres
# Processing Record 9 of Set 3 | sitka
# Processing Record 10 of Set 3 | tiznit
# Processing Record 11 of Set 3 | yuancheng
# Processing Record 12 of Set 3 | japura
# Processing Record 13 of Set 3 | akcakoca
# Processing Record 14 of Set 3 | karlovac
# Processing Record 15 of Set 3 | pisco
# Processing Record 16 of Set 3 | khatanga
# Processing Record 17 of Set 3 | amapa
# Processing Record 18 of Set 3 | sur
# Processing Record 19 of Set 3 | burlington
# Processing Record 20 of Set 3 | amga
# Processing Record 21 of Set 3 | tucuman
# Processing Record 22 of Set 3 | mackenzie
# Processing Record 23 of Set 3 | ussuriysk
# Processing Record 24 of Set 3 | port alfred
# Processing Record 25 of Set 3 | tanabe
# Processing Record 26 of Set 3 | cockburn town
# Processing Record 27 of Set 3 | mathathane
# Processing Record 28 of Set 3 | margate
# Processing Record 29 of Set 3 | gornouralskiy
# City not found. Skipping...
# Processing Record 30 of Set 3 | ipixuna
# Processing Record 31 of Set 3 | portland
# Processing Record 32 of Set 3 | pandan
# Processing Record 33 of Set 3 | coihaique
# Processing Record 34 of Set 3 | saldanha
# Processing Record 35 of Set 3 | khasan
# Processing Record 36 of Set 3 | andra
# Processing Record 37 of Set 3 | acapulco
# Processing Record 38 of Set 3 | batagay-alyta
# Processing Record 39 of Set 3 | birin
# Processing Record 40 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 41 of Set 3 | mar del plata
# Processing Record 42 of Set 3 | kalemie
# Processing Record 43 of Set 3 | forio
# Processing Record 44 of Set 3 | hobart
# Processing Record 45 of Set 3 | alta floresta
# Processing Record 46 of Set 3 | asfi
# Processing Record 47 of Set 3 | puerto ayora
# Processing Record 48 of Set 3 | hobyo
# Processing Record 49 of Set 3 | taoudenni
# Processing Record 50 of Set 3 | vardo
# Processing Record 1 of Set 4 | karratha
# Processing Record 2 of Set 4 | maridi
# Processing Record 3 of Set 4 | saint-augustin
# Processing Record 4 of Set 4 | georgetown
# Processing Record 5 of Set 4 | kruisfontein
# Processing Record 6 of Set 4 | banda aceh
# Processing Record 7 of Set 4 | jinchang
# Processing Record 8 of Set 4 | hilo
# Processing Record 9 of Set 4 | mnogovershinnyy
# Processing Record 10 of Set 4 | smithers
# Processing Record 11 of Set 4 | ocos
# Processing Record 12 of Set 4 | tombouctou
# Processing Record 13 of Set 4 | east london
# Processing Record 14 of Set 4 | talnakh
# Processing Record 15 of Set 4 | omboue
# Processing Record 16 of Set 4 | hardenberg
# Processing Record 17 of Set 4 | wajid
# Processing Record 18 of Set 4 | gombong
# Processing Record 19 of Set 4 | half moon bay
# Processing Record 20 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 4 | paamiut
# Processing Record 22 of Set 4 | valpacos
# Processing Record 23 of Set 4 | port hedland
# Processing Record 24 of Set 4 | souillac
# Processing Record 25 of Set 4 | la rioja
# Processing Record 26 of Set 4 | fukue
# Processing Record 27 of Set 4 | khani
# Processing Record 28 of Set 4 | comodoro rivadavia
# Processing Record 29 of Set 4 | gandai
# Processing Record 30 of Set 4 | hisor
# Processing Record 31 of Set 4 | progreso
# Processing Record 32 of Set 4 | bengkulu
# Processing Record 33 of Set 4 | dikson
# Processing Record 34 of Set 4 | mahebourg
# Processing Record 35 of Set 4 | huron
# Processing Record 36 of Set 4 | dibrugarh
# Processing Record 37 of Set 4 | anqing
# Processing Record 38 of Set 4 | myitkyina
# Processing Record 39 of Set 4 | olafsvik
# Processing Record 40 of Set 4 | bathsheba
# Processing Record 41 of Set 4 | san patricio
# Processing Record 42 of Set 4 | port hardy
# Processing Record 43 of Set 4 | sisimiut
# Processing Record 44 of Set 4 | manono
# Processing Record 45 of Set 4 | san cristobal
# Processing Record 46 of Set 4 | camacha
# Processing Record 47 of Set 4 | gayny
# Processing Record 48 of Set 4 | nauchnyy gorodok
# Processing Record 49 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 50 of Set 4 | majene
# Processing Record 1 of Set 5 | coruripe
# Processing Record 2 of Set 5 | djibo
# Processing Record 3 of Set 5 | saskylakh
# Processing Record 4 of Set 5 | caruray
# Processing Record 5 of Set 5 | arlit
# Processing Record 6 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 7 of Set 5 | ancud
# Processing Record 8 of Set 5 | bambous virieux
# Processing Record 9 of Set 5 | brigantine
# Processing Record 10 of Set 5 | mahajanga
# Processing Record 11 of Set 5 | parker
# Processing Record 12 of Set 5 | svetlaya
# Processing Record 13 of Set 5 | alghero
# Processing Record 14 of Set 5 | tarko-sale
# Processing Record 15 of Set 5 | vorukh
# Processing Record 16 of Set 5 | challans
# Processing Record 17 of Set 5 | san luis
# Processing Record 18 of Set 5 | kayerkan
# Processing Record 19 of Set 5 | wulanhaote
# City not found. Skipping...
# Processing Record 20 of Set 5 | karamay
# City not found. Skipping...
# Processing Record 21 of Set 5 | aakirkeby
# City not found. Skipping...
# Processing Record 22 of Set 5 | saint george
# Processing Record 23 of Set 5 | lalmohan
# Processing Record 24 of Set 5 | kota
# Processing Record 25 of Set 5 | los llanos de aridane
# Processing Record 26 of Set 5 | korla
# Processing Record 27 of Set 5 | saint-philippe
# Processing Record 28 of Set 5 | thinadhoo
# Processing Record 29 of Set 5 | morgan city
# Processing Record 30 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 31 of Set 5 | zhuhai
# Processing Record 32 of Set 5 | zhangjiakou
# Processing Record 33 of Set 5 | luderitz
# Processing Record 34 of Set 5 | black river
# Processing Record 35 of Set 5 | sao miguel do araguaia
# Processing Record 36 of Set 5 | hun
# Processing Record 37 of Set 5 | hamilton
# Processing Record 38 of Set 5 | sao filipe
# Processing Record 39 of Set 5 | bonthe
# Processing Record 40 of Set 5 | benguela
# Processing Record 41 of Set 5 | oranjemund
# Processing Record 42 of Set 5 | oriximina
# Processing Record 43 of Set 5 | machilipatnam
# Processing Record 44 of Set 5 | port hawkesbury
# Processing Record 45 of Set 5 | renfrew
# Processing Record 46 of Set 5 | naze
# Processing Record 47 of Set 5 | kasongo-lunda
# Processing Record 48 of Set 5 | batu
# Processing Record 49 of Set 5 | mayor pablo lagerenza
# Processing Record 50 of Set 5 | vondrozo
# Processing Record 1 of Set 6 | klaksvik
# Processing Record 2 of Set 6 | luunja
# Processing Record 3 of Set 6 | prainha
# Processing Record 4 of Set 6 | rizhao
# Processing Record 5 of Set 6 | xining
# Processing Record 6 of Set 6 | honningsvag
# Processing Record 7 of Set 6 | kushima
# Processing Record 8 of Set 6 | broome
# Processing Record 9 of Set 6 | padang
# Processing Record 10 of Set 6 | qaanaaq
# Processing Record 11 of Set 6 | fuente de oro
# Processing Record 12 of Set 6 | mount gambier
# Processing Record 13 of Set 6 | mopti
# Processing Record 14 of Set 6 | graham
# Processing Record 15 of Set 6 | aksu
# Processing Record 16 of Set 6 | calvinia
# Processing Record 17 of Set 6 | oistins
# Processing Record 18 of Set 6 | upington
# Processing Record 19 of Set 6 | caravelas
# Processing Record 20 of Set 6 | nadym
# Processing Record 21 of Set 6 | nioro
# Processing Record 22 of Set 6 | tezu
# Processing Record 23 of Set 6 | adrar
# Processing Record 24 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 25 of Set 6 | shabo
# Processing Record 26 of Set 6 | inongo
# Processing Record 27 of Set 6 | nyurba
# Processing Record 28 of Set 6 | lompoc
# Processing Record 29 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 30 of Set 6 | shimoda
# Processing Record 31 of Set 6 | norrtalje
# Processing Record 32 of Set 6 | brae
# Processing Record 33 of Set 6 | phalaborwa
# Processing Record 34 of Set 6 | iquique
# Processing Record 35 of Set 6 | esperance
# Processing Record 36 of Set 6 | konevo
# Processing Record 37 of Set 6 | mayumba
# Processing Record 38 of Set 6 | salalah
# Processing Record 39 of Set 6 | pangnirtung
# Processing Record 40 of Set 6 | jardim
# Processing Record 41 of Set 6 | kutum
# Processing Record 42 of Set 6 | taltal
# Processing Record 43 of Set 6 | gazanjyk
# Processing Record 44 of Set 6 | ponta delgada
# Processing Record 45 of Set 6 | archidona
# Processing Record 46 of Set 6 | kharan
# Processing Record 47 of Set 6 | constitucion
# Processing Record 48 of Set 6 | sorland
# Processing Record 49 of Set 6 | meulaboh
# Processing Record 50 of Set 6 | jacqueville
# Processing Record 1 of Set 7 | bekhteyevka
# Processing Record 2 of Set 7 | pundri
# Processing Record 3 of Set 7 | kargasok
# Processing Record 4 of Set 7 | tommot
# Processing Record 5 of Set 7 | canton
# Processing Record 6 of Set 7 | geraldton
# Processing Record 7 of Set 7 | orcopampa
# Processing Record 8 of Set 7 | guerrero negro
# Processing Record 9 of Set 7 | airai
# Processing Record 10 of Set 7 | kletnya
# Processing Record 11 of Set 7 | la ronge
# Processing Record 12 of Set 7 | soyo
# Processing Record 13 of Set 7 | mitsamiouli
# Processing Record 14 of Set 7 | khandyga
# Processing Record 15 of Set 7 | kununurra
# Processing Record 16 of Set 7 | tura
# Processing Record 17 of Set 7 | calama
# Processing Record 18 of Set 7 | sorong
# Processing Record 19 of Set 7 | maumere
# Processing Record 20 of Set 7 | manggar
# Processing Record 21 of Set 7 | saquena
# Processing Record 22 of Set 7 | tanuma
# Processing Record 23 of Set 7 | henties bay
# Processing Record 24 of Set 7 | tessalit
# Processing Record 25 of Set 7 | darhan
# Processing Record 26 of Set 7 | miracema do tocantins
# Processing Record 27 of Set 7 | axim
# Processing Record 28 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 29 of Set 7 | porto novo
# Processing Record 30 of Set 7 | mazamari
# Processing Record 31 of Set 7 | vila franca do campo
# Processing Record 32 of Set 7 | mehran
# Processing Record 33 of Set 7 | pustoshka
# Processing Record 34 of Set 7 | matara
# Processing Record 35 of Set 7 | tucuma
# Processing Record 36 of Set 7 | kaoma
# Processing Record 37 of Set 7 | vestmanna
# Processing Record 38 of Set 7 | tumpat
# Processing Record 39 of Set 7 | nguiu
# City not found. Skipping...
# Processing Record 40 of Set 7 | greeneville
# Processing Record 41 of Set 7 | puerto maldonado
# Processing Record 42 of Set 7 | sulangan
# Processing Record 43 of Set 7 | fortuna
# Processing Record 44 of Set 7 | chadan
# Processing Record 45 of Set 7 | visby
# Processing Record 46 of Set 7 | nishihara
# Processing Record 47 of Set 7 | djambala
# Processing Record 48 of Set 7 | skovorodino
# Processing Record 49 of Set 7 | kingman
# Processing Record 50 of Set 7 | osypenko
# Processing Record 1 of Set 8 | ineu
# Processing Record 2 of Set 8 | aginskoye
# Processing Record 3 of Set 8 | breyten
# Processing Record 4 of Set 8 | hull
# Processing Record 5 of Set 8 | benicarlo
# Processing Record 6 of Set 8 | puerto el triunfo
# Processing Record 7 of Set 8 | nouadhibou
# Processing Record 8 of Set 8 | hays
# Processing Record 9 of Set 8 | mogadishu
# Processing Record 10 of Set 8 | horasan
# Processing Record 11 of Set 8 | mandalgovi
# Processing Record 12 of Set 8 | tsuyama
# Processing Record 13 of Set 8 | sao joao da barra
# Processing Record 14 of Set 8 | bulnes
# Processing Record 15 of Set 8 | tuensang
# Processing Record 16 of Set 8 | galiwinku
# City not found. Skipping...
# Processing Record 17 of Set 8 | baruun-urt
# Processing Record 18 of Set 8 | garden city
# Processing Record 19 of Set 8 | imbituba
# Processing Record 20 of Set 8 | wangqing
# Processing Record 21 of Set 8 | malwan
# City not found. Skipping...
# Processing Record 22 of Set 8 | el suyatal
# Processing Record 23 of Set 8 | ixtapa
# Processing Record 24 of Set 8 | massaguet
# Processing Record 25 of Set 8 | karimpur
# Processing Record 26 of Set 8 | ugoofaaru
# Processing Record 27 of Set 8 | sexsmith
# Processing Record 28 of Set 8 | ozinki
# Processing Record 29 of Set 8 | razole
# Processing Record 30 of Set 8 | dogondoutchi
# Processing Record 31 of Set 8 | kuching
# Processing Record 32 of Set 8 | lilongwe
# Processing Record 33 of Set 8 | coronel bogado
# Processing Record 34 of Set 8 | narkanda
# Processing Record 35 of Set 8 | pasni
# Processing Record 36 of Set 8 | walvis bay
# Processing Record 37 of Set 8 | achisay
# City not found. Skipping...
# Processing Record 38 of Set 8 | vila velha
# Processing Record 39 of Set 8 | lisala
# Processing Record 40 of Set 8 | tongzi
# Processing Record 41 of Set 8 | bougouni
# Processing Record 42 of Set 8 | boende
# Processing Record 43 of Set 8 | berlevag
# Processing Record 44 of Set 8 | iqaluit
# Processing Record 45 of Set 8 | chernyshevskiy
# Processing Record 46 of Set 8 | narsaq
# Processing Record 47 of Set 8 | fort nelson
# Processing Record 48 of Set 8 | loa janan
# Processing Record 49 of Set 8 | boralday
# Processing Record 50 of Set 8 | cidreira
# Processing Record 1 of Set 9 | bulungu
# Processing Record 2 of Set 9 | sinnamary
# Processing Record 3 of Set 9 | salinopolis
# Processing Record 4 of Set 9 | mecca
# Processing Record 5 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 6 of Set 9 | joshimath
# Processing Record 7 of Set 9 | ostrovnoy
# Processing Record 8 of Set 9 | danilovka
# Processing Record 9 of Set 9 | yumen
# Processing Record 10 of Set 9 | ferrol
# Processing Record 11 of Set 9 | necochea
# Processing Record 12 of Set 9 | mbanza-ngungu
# Processing Record 13 of Set 9 | nanlong
# Processing Record 14 of Set 9 | eenhana
# Processing Record 15 of Set 9 | takaungu
# Processing Record 16 of Set 9 | bethlehem
# Processing Record 17 of Set 9 | tak bai
# Processing Record 18 of Set 9 | bethalto
# Processing Record 19 of Set 9 | chabarovice
# Processing Record 20 of Set 9 | uaua
# Processing Record 21 of Set 9 | namibe
# Processing Record 22 of Set 9 | chapais
# Processing Record 23 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 24 of Set 9 | bandarbeyla
# Processing Record 25 of Set 9 | pauini
# Processing Record 26 of Set 9 | kita
# Processing Record 27 of Set 9 | gat
# Processing Record 28 of Set 9 | nautla
# Processing Record 29 of Set 9 | villa rica
# Processing Record 30 of Set 9 | ipatovo
# Processing Record 31 of Set 9 | ternate
# Processing Record 32 of Set 9 | santo tomas
# Processing Record 33 of Set 9 | san matias
# Processing Record 34 of Set 9 | paita
# Processing Record 35 of Set 9 | uruzgan
# Processing Record 36 of Set 9 | sept-iles
# Processing Record 37 of Set 9 | golden
# Processing Record 38 of Set 9 | sechura
# Processing Record 39 of Set 9 | hay river
# Processing Record 40 of Set 9 | rapid valley
# Processing Record 41 of Set 9 | lasa
# Processing Record 42 of Set 9 | batagay
# Processing Record 43 of Set 9 | palwal
# Processing Record 44 of Set 9 | sarkand
# Processing Record 45 of Set 9 | shubarkuduk
# Processing Record 46 of Set 9 | uniao da victoria
# City not found. Skipping...
# Processing Record 47 of Set 9 | sao jose da coroa grande
# Processing Record 48 of Set 9 | miles city
# Processing Record 49 of Set 9 | twentynine palms
# Processing Record 50 of Set 9 | batouri
# Processing Record 1 of Set 10 | biskamzha
# Processing Record 2 of Set 10 | belomorsk
# Processing Record 3 of Set 10 | elyakhin
# Processing Record 4 of Set 10 | bulgan
# Processing Record 5 of Set 10 | marystown
# Processing Record 6 of Set 10 | mbour
# Processing Record 7 of Set 10 | roald
# Processing Record 8 of Set 10 | salvador
# Processing Record 9 of Set 10 | tecoanapa
# Processing Record 10 of Set 10 | asilah
# Processing Record 11 of Set 10 | hofn
# Processing Record 12 of Set 10 | hami
# Processing Record 13 of Set 10 | hammerfest
# Processing Record 14 of Set 10 | atambua
# Processing Record 15 of Set 10 | abadan
# Processing Record 16 of Set 10 | urumqi
# Processing Record 17 of Set 10 | raymond
# Processing Record 18 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 19 of Set 10 | isoka
# Processing Record 20 of Set 10 | cameta
# Processing Record 21 of Set 10 | bahia blanca
# Processing Record 22 of Set 10 | flinders
# Processing Record 23 of Set 10 | muzhi
# Processing Record 24 of Set 10 | severobaykalsk
# Processing Record 25 of Set 10 | immokalee
# Processing Record 26 of Set 10 | litoral del san juan
# City not found. Skipping...
# Processing Record 27 of Set 10 | husavik
# Processing Record 28 of Set 10 | socond
# Processing Record 29 of Set 10 | acara
# Processing Record 30 of Set 10 | bakchar
# Processing Record 31 of Set 10 | lusambo
# Processing Record 32 of Set 10 | arnprior
# Processing Record 33 of Set 10 | port keats
# Processing Record 34 of Set 10 | draguignan
# Processing Record 35 of Set 10 | nantucket
# Processing Record 36 of Set 10 | hualmay
# Processing Record 37 of Set 10 | laguna
# Processing Record 38 of Set 10 | yaan
# Processing Record 39 of Set 10 | ailigandi
# Processing Record 40 of Set 10 | mola di bari
# Processing Record 41 of Set 10 | hanna
# Processing Record 42 of Set 10 | imeni poliny osipenko
# Processing Record 43 of Set 10 | tokzar
# City not found. Skipping...
# Processing Record 44 of Set 10 | caxias
# Processing Record 45 of Set 10 | camopi
# Processing Record 46 of Set 10 | havelock
# Processing Record 47 of Set 10 | ghanzi
# Processing Record 48 of Set 10 | adwa
# Processing Record 49 of Set 10 | puerto pinasco
# City not found. Skipping...
# Processing Record 50 of Set 10 | verkh-usugli
# Processing Record 1 of Set 11 | tucurui
# Processing Record 2 of Set 11 | varzelandia
# Processing Record 3 of Set 11 | port-gentil
# Processing Record 4 of Set 11 | koumra
# Processing Record 5 of Set 11 | george
# Processing Record 6 of Set 11 | manta
# Processing Record 7 of Set 11 | quimper
# Processing Record 8 of Set 11 | phan rang
# City not found. Skipping...
# Processing Record 9 of Set 11 | leh
# Processing Record 10 of Set 11 | nanortalik
# Processing Record 11 of Set 11 | xuddur
# Processing Record 12 of Set 11 | oleksandrivka
# Processing Record 13 of Set 11 | la paz
# Processing Record 14 of Set 11 | romny
# Processing Record 15 of Set 11 | san andres
# Processing Record 16 of Set 11 | mizan teferi
# Processing Record 17 of Set 11 | bambanglipuro
# Processing Record 18 of Set 11 | cambyreta
# City not found. Skipping...
# Processing Record 19 of Set 11 | kavaratti
# Processing Record 20 of Set 11 | mandera
# Processing Record 21 of Set 11 | manbij
# Processing Record 22 of Set 11 | kualakapuas
# Processing Record 23 of Set 11 | waterfoot
# Processing Record 24 of Set 11 | krasnyy chikoy
# Processing Record 25 of Set 11 | atar
# Processing Record 26 of Set 11 | payo
# Processing Record 27 of Set 11 | puerto escondido
# Processing Record 28 of Set 11 | catuday
# Processing Record 29 of Set 11 | orlik
# Processing Record 30 of Set 11 | tarquinia
# Processing Record 31 of Set 11 | umm kaddadah
# Processing Record 32 of Set 11 | lubango
# Processing Record 33 of Set 11 | dhidhdhoo
# Processing Record 34 of Set 11 | edson
# Processing Record 35 of Set 11 | escarcega
# Processing Record 36 of Set 11 | sierre
# Processing Record 37 of Set 11 | rawson
# Processing Record 38 of Set 11 | skjervoy
# Processing Record 39 of Set 11 | iquitos
# Processing Record 40 of Set 11 | banjar
# Processing Record 41 of Set 11 | buraydah
# Processing Record 42 of Set 11 | sijunjung
# Processing Record 43 of Set 11 | amuntai
# Processing Record 44 of Set 11 | paradwip
# City not found. Skipping...
# Processing Record 45 of Set 11 | babanusah
# City not found. Skipping...
# Processing Record 46 of Set 11 | kogon
# Processing Record 47 of Set 11 | inuvik
# Processing Record 48 of Set 11 | whittlesea
# Processing Record 49 of Set 11 | tazovskiy
# Processing Record 50 of Set 11 | san quintin
# Processing Record 1 of Set 12 | tuy hoa
# Processing Record 2 of Set 12 | sembe
# Processing Record 3 of Set 12 | kazalinsk
# City not found. Skipping...
# Processing Record 4 of Set 12 | iskateley
# Processing Record 5 of Set 12 | muros
# Processing Record 6 of Set 12 | mulege
# Processing Record 7 of Set 12 | itoman
# Processing Record 8 of Set 12 | nenjiang
# Processing Record 9 of Set 12 | lumphat
# Processing Record 10 of Set 12 | srikakulam
# Processing Record 11 of Set 12 | matay
# Processing Record 12 of Set 12 | bourbonnais
# Processing Record 13 of Set 12 | leshukonskoye
# Processing Record 14 of Set 12 | corinto
# Processing Record 15 of Set 12 | phun phin
# City not found. Skipping...
# Processing Record 16 of Set 12 | along
# Processing Record 17 of Set 12 | novyy rogachik
# Processing Record 18 of Set 12 | dzaoudzi
# Processing Record 19 of Set 12 | tlaxiaco
# City not found. Skipping...
# Processing Record 20 of Set 12 | caucaia
# Processing Record 21 of Set 12 | cabedelo
# Processing Record 22 of Set 12 | haradok
# Processing Record 23 of Set 12 | linxia
# Processing Record 24 of Set 12 | bongandanga
# Processing Record 25 of Set 12 | paramonga
# Processing Record 26 of Set 12 | laranjeiras do sul
# Processing Record 27 of Set 12 | lewisburg
# Processing Record 28 of Set 12 | ekibastuz
# Processing Record 29 of Set 12 | shasta lake
# Processing Record 30 of Set 12 | tomohon
# Processing Record 31 of Set 12 | high level
# Processing Record 32 of Set 12 | stary sacz
# Processing Record 33 of Set 12 | labrea
# Processing Record 34 of Set 12 | alvdal
# Processing Record 35 of Set 12 | whitewater
# Processing Record 36 of Set 12 | bichena
# Processing Record 37 of Set 12 | eregli
# Processing Record 38 of Set 12 | puerto del rosario
# Processing Record 39 of Set 12 | nyagan
# Processing Record 40 of Set 12 | mantua
# Processing Record 41 of Set 12 | turukhansk
# Processing Record 42 of Set 12 | hindoria
# Processing Record 43 of Set 12 | khuzhir
# Processing Record 44 of Set 12 | estacion coahuila
# Processing Record 45 of Set 12 | esfahan
# Processing Record 46 of Set 12 | pitimbu
# Processing Record 47 of Set 12 | spearfish
# Processing Record 48 of Set 12 | marathopolis
# City not found. Skipping...
# Processing Record 49 of Set 12 | baie-comeau
# Processing Record 50 of Set 12 | buritis
# Processing Record 1 of Set 13 | koboko
# Processing Record 2 of Set 13 | mahon
# Processing Record 3 of Set 13 | sagua de tanamo
# Processing Record 4 of Set 13 | zhanaozen
# Processing Record 5 of Set 13 | eyl
# Processing Record 6 of Set 13 | antofagasta
# Processing Record 7 of Set 13 | valleyview
# Processing Record 8 of Set 13 | andapa
# Processing Record 9 of Set 13 | shihezi
# Processing Record 10 of Set 13 | kautokeino
# Processing Record 11 of Set 13 | okoneshnikovo
# Processing Record 12 of Set 13 | dudinka
# Processing Record 13 of Set 13 | road town
# Processing Record 14 of Set 13 | gangapur
# Processing Record 15 of Set 13 | miguel hidalgo
# Processing Record 16 of Set 13 | nador
# Processing Record 17 of Set 13 | huarmey
# Processing Record 18 of Set 13 | ovre ardal
# Processing Record 19 of Set 13 | ifakara
# Processing Record 20 of Set 13 | yashkul
# Processing Record 21 of Set 13 | beni
# Processing Record 22 of Set 13 | santa rosa
# Processing Record 23 of Set 13 | conceicao do araguaia
# Processing Record 24 of Set 13 | ligayan
# Processing Record 25 of Set 13 | culpeper
# Processing Record 26 of Set 13 | zanatepec
# City not found. Skipping...
# Processing Record 27 of Set 13 | aldan
# Processing Record 28 of Set 13 | denpasar
# Processing Record 29 of Set 13 | stoyba
# City not found. Skipping...
# Processing Record 30 of Set 13 | yerofey pavlovich
# Processing Record 31 of Set 13 | havoysund
# Processing Record 32 of Set 13 | ketchikan
# Processing Record 33 of Set 13 | hambantota
# Processing Record 34 of Set 13 | sume
# Processing Record 35 of Set 13 | derzhavinsk
# Processing Record 36 of Set 13 | maua
# Processing Record 37 of Set 13 | jiddah
# City not found. Skipping...
# Processing Record 38 of Set 13 | sao gabriel da cachoeira
# Processing Record 39 of Set 13 | santa pola
# Processing Record 40 of Set 13 | cuamba
# Processing Record 41 of Set 13 | voyvozh
# Processing Record 42 of Set 13 | krasnoselkup
# Processing Record 43 of Set 13 | lukuledi
# Processing Record 44 of Set 13 | son tay
# Processing Record 45 of Set 13 | woodstock
# Processing Record 46 of Set 13 | manga
# Processing Record 47 of Set 13 | yar-sale
# Processing Record 48 of Set 13 | saint-fabien
# City not found. Skipping...
# Processing Record 49 of Set 13 | banfora
# Processing Record 50 of Set 13 | vostok
# Processing Record 1 of Set 14 | altamont
# Processing Record 2 of Set 14 | ngukurr
# City not found. Skipping...
# Processing Record 3 of Set 14 | sahrak
# City not found. Skipping...
# Processing Record 4 of Set 14 | nueve de julio
# Processing Record 5 of Set 14 | cherepovets
# Processing Record 6 of Set 14 | quatre cocos
# Processing Record 7 of Set 14 | thongwa
# Processing Record 8 of Set 14 | mana
# Processing Record 9 of Set 14 | defiance
# Processing Record 10 of Set 14 | pergamino
# Processing Record 11 of Set 14 | sidney
# Processing Record 12 of Set 14 | wanning
# Processing Record 13 of Set 14 | grindavik
# Processing Record 14 of Set 14 | shar
# Processing Record 15 of Set 14 | bridlington
# Processing Record 16 of Set 14 | barsi
# Processing Record 17 of Set 14 | weiz
# Processing Record 18 of Set 14 | dongzhen
# Processing Record 19 of Set 14 | kalabo
# Processing Record 20 of Set 14 | pingliang
# Processing Record 21 of Set 14 | santa cruz
# Processing Record 22 of Set 14 | fenyi
# Processing Record 23 of Set 14 | anloga
# Processing Record 24 of Set 14 | pueblo
# Processing Record 25 of Set 14 | beni suef
# Processing Record 26 of Set 14 | balad
# Processing Record 27 of Set 14 | saint-prosper
# Processing Record 28 of Set 14 | guntakal
# Processing Record 29 of Set 14 | ambilobe
# Processing Record 30 of Set 14 | alegrete
# Processing Record 31 of Set 14 | fort stewart
# Processing Record 32 of Set 14 | totolapan
# Processing Record 33 of Set 14 | marienburg
# Processing Record 34 of Set 14 | richards bay
# Processing Record 35 of Set 14 | am timan
# Processing Record 36 of Set 14 | batsfjord
# Processing Record 37 of Set 14 | kudahuvadhoo
# Processing Record 38 of Set 14 | bogovarovo
# Processing Record 39 of Set 14 | chifeng
# Processing Record 40 of Set 14 | boddam
# Processing Record 41 of Set 14 | chulym
# Processing Record 42 of Set 14 | werda
# Processing Record 43 of Set 14 | tokur
# Processing Record 44 of Set 14 | medea
# Processing Record 45 of Set 14 | nyakahanga
# Processing Record 46 of Set 14 | san jeronimo
# Processing Record 47 of Set 14 | sturgeon bay
# Processing Record 48 of Set 14 | iberia
# Processing Record 49 of Set 14 | namtsy
# Processing Record 50 of Set 14 | bur gabo
# City not found. Skipping...
# Processing Record 1 of Set 15 | beloha
# Processing Record 2 of Set 15 | pochutla
# Processing Record 3 of Set 15 | jurm
# Processing Record 4 of Set 15 | nalut
# Processing Record 5 of Set 15 | dien bien
# City not found. Skipping...
# Processing Record 6 of Set 15 | ondorhaan
# City not found. Skipping...
# Processing Record 7 of Set 15 | waingapu
# Processing Record 8 of Set 15 | osoyoos
# Processing Record 9 of Set 15 | praxedis guerrero
# Processing Record 10 of Set 15 | riyadh
# Processing Record 11 of Set 15 | port lincoln
# Processing Record 12 of Set 15 | lima
# Processing Record 13 of Set 15 | ibb
# Processing Record 14 of Set 15 | kirsanov
# Processing Record 15 of Set 15 | galle
# Processing Record 16 of Set 15 | marabba
# Processing Record 17 of Set 15 | san carlos de bariloche
# Processing Record 18 of Set 15 | stephenville
# Processing Record 19 of Set 15 | thunder bay
# Processing Record 20 of Set 15 | nizhnekamsk
# Processing Record 21 of Set 15 | samoded
# Processing Record 22 of Set 15 | selkirk
# Processing Record 23 of Set 15 | mwense
# Processing Record 24 of Set 15 | yinchuan
# Processing Record 25 of Set 15 | evanston
# Processing Record 26 of Set 15 | pringsewu
# Processing Record 27 of Set 15 | dosso
# Processing Record 28 of Set 15 | karwar
# Processing Record 29 of Set 15 | nekhayevskiy
# Processing Record 30 of Set 15 | vysokaya gora
# Processing Record 31 of Set 15 | buchanan
# Processing Record 32 of Set 15 | rietavas
# Processing Record 33 of Set 15 | murindo
# Processing Record 34 of Set 15 | ha tinh
# Processing Record 35 of Set 15 | dalton
# Processing Record 36 of Set 15 | baturaja
# Processing Record 37 of Set 15 | aksha
# Processing Record 38 of Set 15 | windhoek
# Processing Record 39 of Set 15 | tukrah
# Processing Record 40 of Set 15 | pemangkat
# Processing Record 41 of Set 15 | stornoway
# Processing Record 42 of Set 15 | port-cartier
# Processing Record 43 of Set 15 | beinamar
# Processing Record 44 of Set 15 | kumluca
# Processing Record 45 of Set 15 | invermere
# Processing Record 46 of Set 15 | bindura
# Processing Record 47 of Set 15 | kuusamo
# Processing Record 48 of Set 15 | ventspils
# Processing Record 49 of Set 15 | takoradi
# Processing Record 50 of Set 15 | conakry
# Processing Record 1 of Set 16 | kirovskiy
# Processing Record 2 of Set 16 | okitipupa
# Processing Record 3 of Set 16 | elesbao veloso
# Processing Record 4 of Set 16 | magnitogorsk
# Processing Record 5 of Set 16 | madera
# Processing Record 6 of Set 16 | la paz centro
# Processing Record 7 of Set 16 | cazaje
# City not found. Skipping...
# Processing Record 8 of Set 16 | pombas
# Processing Record 9 of Set 16 | deputatskiy
# Processing Record 10 of Set 16 | berezovyy
# Processing Record 11 of Set 16 | sao raimundo nonato
# Processing Record 12 of Set 16 | gaoua
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Arraial Do Cabo      BR -22.9661  -42.0278     76.96        57           0
# 1        Hithadhoo      MV  -0.6000   73.0833     84.61        77          39
# 2         Menongue      AO -14.6585   17.6910     63.14        54           2
# 3           Dingle      PH  10.9995  122.6711     77.54        89         100
# 4        Cape Town      ZA -33.9258   18.4232     57.61        83           0
# 5            Rafai      CF   4.9500   23.9167     72.66        90         100
# 6   Georgiyevskoye      RU  58.7310   45.0240     33.76        99         100
# 7         Victoria      HK  22.2855  114.1577     77.38        90         100
# 8     Punta Arenas      CL -53.1500  -70.9167     48.31        76          20
# 9           Ovalle      CL -30.5983  -71.2003     78.66        29           6
#
#    Wind Speed Current Description
# 0        9.22           clear sky
# 1       20.02    scattered clouds
# 2        4.94           clear sky
# 3        7.49     overcast clouds
# 4        4.61           clear sky
# 5        6.76          light rain
# 6       13.22          light snow
# 7       13.00          light rain
# 8       29.93          few clouds
# 9        4.97           clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_Data/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
