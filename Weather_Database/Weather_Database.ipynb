# %% [markdown]
# # Deliverable 1 Retrieve Weather Data

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy  import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-140.000, high=140.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 783

# %%
#Print last city
print(city)
# Out:
# castro

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9d822535a4aff6e3f3ae17e65e288f54

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description" : city_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | new norfolk
# Processing Record 3 of Set 1 | tha mai
# Processing Record 4 of Set 1 | shingu
# Processing Record 5 of Set 1 | garmsar
# Processing Record 6 of Set 1 | hermanus
# Processing Record 7 of Set 1 | khash
# Processing Record 8 of Set 1 | lucapa
# Processing Record 9 of Set 1 | marsa matruh
# Processing Record 10 of Set 1 | yuncheng
# Processing Record 11 of Set 1 | punta arenas
# Processing Record 12 of Set 1 | atuona
# Processing Record 13 of Set 1 | port alfred
# Processing Record 14 of Set 1 | nova olimpia
# Processing Record 15 of Set 1 | norman wells
# Processing Record 16 of Set 1 | dikson
# Processing Record 17 of Set 1 | fort saint john
# City not found. Skipping...
# Processing Record 18 of Set 1 | cravo norte
# Processing Record 19 of Set 1 | hithadhoo
# Processing Record 20 of Set 1 | albany
# Processing Record 21 of Set 1 | busselton
# Processing Record 22 of Set 1 | jamestown
# Processing Record 23 of Set 1 | kozachi laheri
# Processing Record 24 of Set 1 | quang ngai
# Processing Record 25 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 26 of Set 1 | hilo
# Processing Record 27 of Set 1 | saskylakh
# Processing Record 28 of Set 1 | east london
# Processing Record 29 of Set 1 | tasiilaq
# Processing Record 30 of Set 1 | puerto ayora
# Processing Record 31 of Set 1 | alberton
# Processing Record 32 of Set 1 | bengkulu
# Processing Record 33 of Set 1 | ostrovnoy
# Processing Record 34 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 35 of Set 1 | canaries
# Processing Record 36 of Set 1 | virginia beach
# Processing Record 37 of Set 1 | athabasca
# Processing Record 38 of Set 1 | khatanga
# Processing Record 39 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 40 of Set 1 | rreshen
# Processing Record 41 of Set 1 | watertown
# Processing Record 42 of Set 1 | iraquara
# Processing Record 43 of Set 1 | taoudenni
# Processing Record 44 of Set 1 | batticaloa
# Processing Record 45 of Set 1 | rikitea
# Processing Record 46 of Set 1 | bonavista
# Processing Record 47 of Set 1 | villazon
# Processing Record 48 of Set 1 | louisbourg
# City not found. Skipping...
# Processing Record 49 of Set 1 | thompson
# Processing Record 50 of Set 1 | vondrozo
# Processing Record 1 of Set 2 | hofn
# Processing Record 2 of Set 2 | tuktoyaktuk
# Processing Record 3 of Set 2 | muzhi
# Processing Record 4 of Set 2 | georgetown
# Processing Record 5 of Set 2 | adeje
# Processing Record 6 of Set 2 | bambous virieux
# Processing Record 7 of Set 2 | clyde river
# Processing Record 8 of Set 2 | bredasdorp
# Processing Record 9 of Set 2 | beian
# Processing Record 10 of Set 2 | padang
# Processing Record 11 of Set 2 | bahia honda
# Processing Record 12 of Set 2 | iquitos
# Processing Record 13 of Set 2 | chumikan
# Processing Record 14 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 2 | kitgum
# Processing Record 16 of Set 2 | karaul
# City not found. Skipping...
# Processing Record 17 of Set 2 | natitingou
# Processing Record 18 of Set 2 | lebu
# Processing Record 19 of Set 2 | khasan
# Processing Record 20 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 21 of Set 2 | viligili
# City not found. Skipping...
# Processing Record 22 of Set 2 | pacific grove
# Processing Record 23 of Set 2 | chuy
# Processing Record 24 of Set 2 | muisne
# Processing Record 25 of Set 2 | san patricio
# Processing Record 26 of Set 2 | carnarvon
# Processing Record 27 of Set 2 | ribeira grande
# Processing Record 28 of Set 2 | port elizabeth
# Processing Record 29 of Set 2 | cabra
# Processing Record 30 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 31 of Set 2 | shenzhen
# Processing Record 32 of Set 2 | cape town
# Processing Record 33 of Set 2 | dzerzhinskoye
# Processing Record 34 of Set 2 | dingle
# Processing Record 35 of Set 2 | road town
# Processing Record 36 of Set 2 | vardo
# Processing Record 37 of Set 2 | kongolo
# Processing Record 38 of Set 2 | spas
# Processing Record 39 of Set 2 | longyearbyen
# Processing Record 40 of Set 2 | husavik
# Processing Record 41 of Set 2 | portland
# Processing Record 42 of Set 2 | casma
# Processing Record 43 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 44 of Set 2 | ondarroa
# Processing Record 45 of Set 2 | lauria
# Processing Record 46 of Set 2 | dalvik
# Processing Record 47 of Set 2 | broome
# Processing Record 48 of Set 2 | klaksvik
# Processing Record 49 of Set 2 | qaanaaq
# Processing Record 50 of Set 2 | celestun
# Processing Record 1 of Set 3 | saldanha
# Processing Record 2 of Set 3 | namibe
# Processing Record 3 of Set 3 | talnakh
# Processing Record 4 of Set 3 | kulu
# Processing Record 5 of Set 3 | miraflores
# Processing Record 6 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 7 of Set 3 | yellowknife
# Processing Record 8 of Set 3 | diamantino
# Processing Record 9 of Set 3 | sao miguel do araguaia
# Processing Record 10 of Set 3 | jimeta
# Processing Record 11 of Set 3 | victoria
# Processing Record 12 of Set 3 | luanda
# Processing Record 13 of Set 3 | zhanakorgan
# Processing Record 14 of Set 3 | sistranda
# Processing Record 15 of Set 3 | mendi
# Processing Record 16 of Set 3 | mahebourg
# Processing Record 17 of Set 3 | west bay
# Processing Record 18 of Set 3 | aktau
# Processing Record 19 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 20 of Set 3 | mirnyy
# Processing Record 21 of Set 3 | ye
# City not found. Skipping...
# Processing Record 22 of Set 3 | courtenay
# Processing Record 23 of Set 3 | tabou
# Processing Record 24 of Set 3 | torbay
# Processing Record 25 of Set 3 | gueret
# Processing Record 26 of Set 3 | korla
# Processing Record 27 of Set 3 | podujevo
# Processing Record 28 of Set 3 | tiksi
# Processing Record 29 of Set 3 | suoyarvi
# Processing Record 30 of Set 3 | afmadu
# City not found. Skipping...
# Processing Record 31 of Set 3 | ouadda
# Processing Record 32 of Set 3 | port hardy
# Processing Record 33 of Set 3 | rodez
# Processing Record 34 of Set 3 | rolim de moura
# City not found. Skipping...
# Processing Record 35 of Set 3 | angol
# Processing Record 36 of Set 3 | uporovo
# Processing Record 37 of Set 3 | lander
# Processing Record 38 of Set 3 | linxia
# Processing Record 39 of Set 3 | maniitsoq
# Processing Record 40 of Set 3 | sembe
# Processing Record 41 of Set 3 | roebourne
# Processing Record 42 of Set 3 | bandarbeyla
# Processing Record 43 of Set 3 | cabedelo
# Processing Record 44 of Set 3 | cayenne
# Processing Record 45 of Set 3 | neuquen
# Processing Record 46 of Set 3 | nouakchott
# Processing Record 47 of Set 3 | pangnirtung
# Processing Record 48 of Set 3 | rurrenabaque
# Processing Record 49 of Set 3 | kyra
# Processing Record 50 of Set 3 | mar del plata
# Processing Record 1 of Set 4 | general pico
# Processing Record 2 of Set 4 | jalu
# Processing Record 3 of Set 4 | atyrau
# Processing Record 4 of Set 4 | ruteng
# Processing Record 5 of Set 4 | ponta do sol
# Processing Record 6 of Set 4 | cidreira
# Processing Record 7 of Set 4 | linhai
# Processing Record 8 of Set 4 | petrolina
# Processing Record 9 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 4 | mount gambier
# Processing Record 11 of Set 4 | kruisfontein
# Processing Record 12 of Set 4 | grand centre
# City not found. Skipping...
# Processing Record 13 of Set 4 | kununurra
# Processing Record 14 of Set 4 | castro
# Processing Record 15 of Set 4 | riviere-au-renard
# Processing Record 16 of Set 4 | chikwawa
# Processing Record 17 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 18 of Set 4 | paita
# Processing Record 19 of Set 4 | necochea
# Processing Record 20 of Set 4 | huanren
# Processing Record 21 of Set 4 | arraial do cabo
# Processing Record 22 of Set 4 | san luis
# Processing Record 23 of Set 4 | bud
# Processing Record 24 of Set 4 | airai
# Processing Record 25 of Set 4 | swift current
# Processing Record 26 of Set 4 | alugan
# Processing Record 27 of Set 4 | muli
# Processing Record 28 of Set 4 | laguna
# Processing Record 29 of Set 4 | takoradi
# Processing Record 30 of Set 4 | tanete
# Processing Record 31 of Set 4 | kilmez
# City not found. Skipping...
# Processing Record 32 of Set 4 | dalbeattie
# Processing Record 33 of Set 4 | east linton
# Processing Record 34 of Set 4 | constitucion
# Processing Record 35 of Set 4 | dofteana
# Processing Record 36 of Set 4 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 37 of Set 4 | shrewsbury
# Processing Record 38 of Set 4 | nouadhibou
# Processing Record 39 of Set 4 | sioux lookout
# Processing Record 40 of Set 4 | tura
# Processing Record 41 of Set 4 | gravelbourg
# Processing Record 42 of Set 4 | mayo
# Processing Record 43 of Set 4 | grand gaube
# Processing Record 44 of Set 4 | vila velha
# Processing Record 45 of Set 4 | colares
# Processing Record 46 of Set 4 | port hedland
# Processing Record 47 of Set 4 | iqaluit
# Processing Record 48 of Set 4 | coahuayana
# Processing Record 49 of Set 4 | seguela
# Processing Record 50 of Set 4 | asfi
# Processing Record 1 of Set 5 | biskamzha
# Processing Record 2 of Set 5 | formoso do araguaia
# City not found. Skipping...
# Processing Record 3 of Set 5 | ilulissat
# Processing Record 4 of Set 5 | ancud
# Processing Record 5 of Set 5 | esperance
# Processing Record 6 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 7 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 5 | shitanjing
# Processing Record 9 of Set 5 | berlevag
# Processing Record 10 of Set 5 | shymkent
# Processing Record 11 of Set 5 | usinsk
# Processing Record 12 of Set 5 | naze
# Processing Record 13 of Set 5 | geraldton
# Processing Record 14 of Set 5 | liseleje
# Processing Record 15 of Set 5 | fountain
# Processing Record 16 of Set 5 | pemangkat
# Processing Record 17 of Set 5 | fort nelson
# Processing Record 18 of Set 5 | turkistan
# Processing Record 19 of Set 5 | skibbereen
# Processing Record 20 of Set 5 | ucluelet
# Processing Record 21 of Set 5 | la tuque
# Processing Record 22 of Set 5 | baiao
# Processing Record 23 of Set 5 | hobart
# Processing Record 24 of Set 5 | touros
# Processing Record 25 of Set 5 | poyarkovo
# Processing Record 26 of Set 5 | flin flon
# Processing Record 27 of Set 5 | pokhara
# Processing Record 28 of Set 5 | dwarka
# Processing Record 29 of Set 5 | hamilton
# Processing Record 30 of Set 5 | palmas bellas
# Processing Record 31 of Set 5 | sayyan
# Processing Record 32 of Set 5 | khani
# Processing Record 33 of Set 5 | biancavilla
# Processing Record 34 of Set 5 | tanjong tokong
# City not found. Skipping...
# Processing Record 35 of Set 5 | tucuman
# Processing Record 36 of Set 5 | wahran
# City not found. Skipping...
# Processing Record 37 of Set 5 | sucua
# Processing Record 38 of Set 5 | chala
# Processing Record 39 of Set 5 | ullapool
# Processing Record 40 of Set 5 | qianjiang
# Processing Record 41 of Set 5 | dhangadhi
# Processing Record 42 of Set 5 | koratla
# Processing Record 43 of Set 5 | richards bay
# Processing Record 44 of Set 5 | strelka
# Processing Record 45 of Set 5 | kidal
# Processing Record 46 of Set 5 | saint-francois
# Processing Record 47 of Set 5 | salalah
# Processing Record 48 of Set 5 | matay
# Processing Record 49 of Set 5 | pisco
# Processing Record 50 of Set 5 | melfi
# Processing Record 1 of Set 6 | san cristobal
# Processing Record 2 of Set 6 | placido de castro
# Processing Record 3 of Set 6 | lardos
# Processing Record 4 of Set 6 | santiago
# Processing Record 5 of Set 6 | riachao das neves
# Processing Record 6 of Set 6 | wattegama
# Processing Record 7 of Set 6 | sabha
# Processing Record 8 of Set 6 | ibanda
# Processing Record 9 of Set 6 | jumla
# Processing Record 10 of Set 6 | kutum
# Processing Record 11 of Set 6 | muyezerskiy
# Processing Record 12 of Set 6 | bitung
# Processing Record 13 of Set 6 | rawson
# Processing Record 14 of Set 6 | rio gallegos
# Processing Record 15 of Set 6 | valentin gomez farias
# Processing Record 16 of Set 6 | rawlins
# Processing Record 17 of Set 6 | mgandu
# Processing Record 18 of Set 6 | rabo de peixe
# Processing Record 19 of Set 6 | cap malheureux
# Processing Record 20 of Set 6 | nalut
# Processing Record 21 of Set 6 | parrita
# Processing Record 22 of Set 6 | nanortalik
# Processing Record 23 of Set 6 | aporawan
# City not found. Skipping...
# Processing Record 24 of Set 6 | axim
# Processing Record 25 of Set 6 | agdam
# Processing Record 26 of Set 6 | tukums
# Processing Record 27 of Set 6 | lons-le-saunier
# Processing Record 28 of Set 6 | beloha
# Processing Record 29 of Set 6 | aragarcas
# Processing Record 30 of Set 6 | zastavna
# Processing Record 31 of Set 6 | sechura
# Processing Record 32 of Set 6 | kegayli
# City not found. Skipping...
# Processing Record 33 of Set 6 | puerto madryn
# Processing Record 34 of Set 6 | high rock
# Processing Record 35 of Set 6 | krasnoselkup
# Processing Record 36 of Set 6 | oranjemund
# Processing Record 37 of Set 6 | rundu
# Processing Record 38 of Set 6 | kristinehamn
# Processing Record 39 of Set 6 | katobu
# Processing Record 40 of Set 6 | olafsvik
# Processing Record 41 of Set 6 | muroto
# Processing Record 42 of Set 6 | medea
# Processing Record 43 of Set 6 | luderitz
# Processing Record 44 of Set 6 | emborion
# Processing Record 45 of Set 6 | coroico
# Processing Record 46 of Set 6 | simbahan
# Processing Record 47 of Set 6 | comodoro rivadavia
# Processing Record 48 of Set 6 | nyandoma
# Processing Record 49 of Set 6 | ayolas
# Processing Record 50 of Set 6 | inirida
# Processing Record 1 of Set 7 | noshiro
# Processing Record 2 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 3 of Set 7 | le mars
# Processing Record 4 of Set 7 | chicama
# Processing Record 5 of Set 7 | awjilah
# Processing Record 6 of Set 7 | ferrol
# Processing Record 7 of Set 7 | saint-vallier
# Processing Record 8 of Set 7 | nueve de julio
# Processing Record 9 of Set 7 | tres picos
# Processing Record 10 of Set 7 | dawei
# Processing Record 11 of Set 7 | acapulco
# Processing Record 12 of Set 7 | cabo san lucas
# Processing Record 13 of Set 7 | shelburne
# Processing Record 14 of Set 7 | matara
# Processing Record 15 of Set 7 | maceio
# Processing Record 16 of Set 7 | halifax
# Processing Record 17 of Set 7 | ilhabela
# Processing Record 18 of Set 7 | banjar
# Processing Record 19 of Set 7 | katherine
# Processing Record 20 of Set 7 | riberalta
# Processing Record 21 of Set 7 | cody
# Processing Record 22 of Set 7 | luang prabang
# Processing Record 23 of Set 7 | niamey
# Processing Record 24 of Set 7 | bathsheba
# Processing Record 25 of Set 7 | vadlapudi
# Processing Record 26 of Set 7 | the valley
# Processing Record 27 of Set 7 | mogok
# Processing Record 28 of Set 7 | adrar
# Processing Record 29 of Set 7 | santona
# Processing Record 30 of Set 7 | raudeberg
# Processing Record 31 of Set 7 | aksarka
# Processing Record 32 of Set 7 | upernavik
# Processing Record 33 of Set 7 | sao filipe
# Processing Record 34 of Set 7 | iranshahr
# Processing Record 35 of Set 7 | kamenka
# Processing Record 36 of Set 7 | spearfish
# Processing Record 37 of Set 7 | pavilosta
# Processing Record 38 of Set 7 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 39 of Set 7 | coihaique
# Processing Record 40 of Set 7 | udachnyy
# Processing Record 41 of Set 7 | karpathos
# Processing Record 42 of Set 7 | imbituba
# Processing Record 43 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 44 of Set 7 | tanout
# Processing Record 45 of Set 7 | pochutla
# Processing Record 46 of Set 7 | sarishabari
# Processing Record 47 of Set 7 | alencon
# Processing Record 48 of Set 7 | stoyba
# City not found. Skipping...
# Processing Record 49 of Set 7 | saint george
# Processing Record 50 of Set 7 | xuddur
# Processing Record 1 of Set 8 | triunfo
# Processing Record 2 of Set 8 | lazaro cardenas
# Processing Record 3 of Set 8 | arkansas city
# Processing Record 4 of Set 8 | garowe
# Processing Record 5 of Set 8 | kemin
# Processing Record 6 of Set 8 | aflu
# City not found. Skipping...
# Processing Record 7 of Set 8 | santa maria
# Processing Record 8 of Set 8 | mehamn
# Processing Record 9 of Set 8 | north bend
# Processing Record 10 of Set 8 | nuuk
# Processing Record 11 of Set 8 | guerrero negro
# Processing Record 12 of Set 8 | beaufort
# Processing Record 13 of Set 8 | babu
# Processing Record 14 of Set 8 | rawalpindi
# Processing Record 15 of Set 8 | zolotonosha
# Processing Record 16 of Set 8 | yuanping
# Processing Record 17 of Set 8 | ambovombe
# Processing Record 18 of Set 8 | voyvozh
# Processing Record 19 of Set 8 | mrirt
# City not found. Skipping...
# Processing Record 20 of Set 8 | toyooka
# Processing Record 21 of Set 8 | mantua
# Processing Record 22 of Set 8 | altamont
# Processing Record 23 of Set 8 | camacha
# Processing Record 24 of Set 8 | mogadishu
# Processing Record 25 of Set 8 | gamba
# Processing Record 26 of Set 8 | sant
# Processing Record 27 of Set 8 | olga
# Processing Record 28 of Set 8 | malwan
# City not found. Skipping...
# Processing Record 29 of Set 8 | pitea
# Processing Record 30 of Set 8 | bulgan
# Processing Record 31 of Set 8 | mega
# Processing Record 32 of Set 8 | malakal
# Processing Record 33 of Set 8 | asayita
# City not found. Skipping...
# Processing Record 34 of Set 8 | tazovskiy
# Processing Record 35 of Set 8 | sao gabriel da cachoeira
# Processing Record 36 of Set 8 | teknaf
# Processing Record 37 of Set 8 | saint-philippe
# Processing Record 38 of Set 8 | fortuna
# Processing Record 39 of Set 8 | ordzhonikidze
# Processing Record 40 of Set 8 | marzuq
# Processing Record 41 of Set 8 | ulaangom
# Processing Record 42 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 43 of Set 8 | mehran
# Processing Record 44 of Set 8 | altay
# Processing Record 45 of Set 8 | zhigansk
# Processing Record 46 of Set 8 | hisor
# Processing Record 47 of Set 8 | palang
# Processing Record 48 of Set 8 | grindavik
# Processing Record 49 of Set 8 | varzea da palma
# Processing Record 50 of Set 8 | thinadhoo
# Processing Record 1 of Set 9 | bubaque
# Processing Record 2 of Set 9 | botwood
# Processing Record 3 of Set 9 | scarborough
# Processing Record 4 of Set 9 | gondanglegi
# Processing Record 5 of Set 9 | nadym
# Processing Record 6 of Set 9 | lalmohan
# Processing Record 7 of Set 9 | lompoc
# Processing Record 8 of Set 9 | itarema
# Processing Record 9 of Set 9 | marawi
# Processing Record 10 of Set 9 | cascais
# Processing Record 11 of Set 9 | mahajanga
# Processing Record 12 of Set 9 | smithers
# Processing Record 13 of Set 9 | yulara
# Processing Record 14 of Set 9 | codrington
# Processing Record 15 of Set 9 | kemijarvi
# Processing Record 16 of Set 9 | hobyo
# Processing Record 17 of Set 9 | minyar
# Processing Record 18 of Set 9 | ballina
# Processing Record 19 of Set 9 | macau
# Processing Record 20 of Set 9 | sorland
# Processing Record 21 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 22 of Set 9 | kiunga
# Processing Record 23 of Set 9 | astoria
# Processing Record 24 of Set 9 | alta floresta
# Processing Record 25 of Set 9 | xining
# Processing Record 26 of Set 9 | rock hill
# Processing Record 27 of Set 9 | coos bay
# Processing Record 28 of Set 9 | leh
# Processing Record 29 of Set 9 | thibodaux
# Processing Record 30 of Set 9 | padre bernardo
# Processing Record 31 of Set 9 | balikpapan
# Processing Record 32 of Set 9 | tashtyp
# Processing Record 33 of Set 9 | roald
# Processing Record 34 of Set 9 | san pedro
# Processing Record 35 of Set 9 | champagnole
# Processing Record 36 of Set 9 | bonfim
# Processing Record 37 of Set 9 | lake city
# Processing Record 38 of Set 9 | kavaratti
# Processing Record 39 of Set 9 | faya
# Processing Record 40 of Set 9 | hwange
# Processing Record 41 of Set 9 | nuevo progreso
# Processing Record 42 of Set 9 | jardim
# Processing Record 43 of Set 9 | sao joao da barra
# Processing Record 44 of Set 9 | ust-kut
# Processing Record 45 of Set 9 | baykit
# Processing Record 46 of Set 9 | kurumkan
# Processing Record 47 of Set 9 | sept-iles
# Processing Record 48 of Set 9 | southport
# Processing Record 49 of Set 9 | meadow lake
# Processing Record 50 of Set 9 | tocopilla
# Processing Record 1 of Set 10 | trinidad
# Processing Record 2 of Set 10 | huarmey
# Processing Record 3 of Set 10 | hornepayne
# Processing Record 4 of Set 10 | atambua
# Processing Record 5 of Set 10 | lasa
# Processing Record 6 of Set 10 | nioro
# Processing Record 7 of Set 10 | eenhana
# Processing Record 8 of Set 10 | zhuanghe
# Processing Record 9 of Set 10 | meulaboh
# Processing Record 10 of Set 10 | verkhoyansk
# Processing Record 11 of Set 10 | skelleftea
# Processing Record 12 of Set 10 | barabai
# Processing Record 13 of Set 10 | kvarkeno
# Processing Record 14 of Set 10 | grenfell
# Processing Record 15 of Set 10 | atasu
# Processing Record 16 of Set 10 | dryden
# Processing Record 17 of Set 10 | port keats
# Processing Record 18 of Set 10 | contamana
# Processing Record 19 of Set 10 | maihar
# Processing Record 20 of Set 10 | juegang
# Processing Record 21 of Set 10 | esmeralda
# Processing Record 22 of Set 10 | cockburn town
# Processing Record 23 of Set 10 | kon tum
# Processing Record 24 of Set 10 | itagi
# Processing Record 25 of Set 10 | lake havasu city
# Processing Record 26 of Set 10 | romitan
# Processing Record 27 of Set 10 | itambacuri
# Processing Record 28 of Set 10 | venice
# Processing Record 29 of Set 10 | jabiru
# City not found. Skipping...
# Processing Record 30 of Set 10 | ambilobe
# Processing Record 31 of Set 10 | nemours
# Processing Record 32 of Set 10 | timizart
# Processing Record 33 of Set 10 | barwadih
# Processing Record 34 of Set 10 | eureka
# Processing Record 35 of Set 10 | logrono
# Processing Record 36 of Set 10 | vyartsilya
# Processing Record 37 of Set 10 | pallisa
# Processing Record 38 of Set 10 | batangafo
# Processing Record 39 of Set 10 | lere
# Processing Record 40 of Set 10 | greenwood
# Processing Record 41 of Set 10 | dabwali
# Processing Record 42 of Set 10 | hella
# Processing Record 43 of Set 10 | seoul
# Processing Record 44 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 45 of Set 10 | baghdad
# Processing Record 46 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 47 of Set 10 | panzhihua
# Processing Record 48 of Set 10 | sacama
# Processing Record 49 of Set 10 | dicabisagan
# Processing Record 50 of Set 10 | knysna
# Processing Record 1 of Set 11 | shkoder
# Processing Record 2 of Set 11 | port lincoln
# Processing Record 3 of Set 11 | pasighat
# Processing Record 4 of Set 11 | swan river
# Processing Record 5 of Set 11 | nago
# Processing Record 6 of Set 11 | lydenburg
# Processing Record 7 of Set 11 | huajuapan
# City not found. Skipping...
# Processing Record 8 of Set 11 | flinders
# Processing Record 9 of Set 11 | ende
# Processing Record 10 of Set 11 | galiwinku
# City not found. Skipping...
# Processing Record 11 of Set 11 | dallas
# Processing Record 12 of Set 11 | vrede
# Processing Record 13 of Set 11 | douentza
# Processing Record 14 of Set 11 | ukiah
# Processing Record 15 of Set 11 | kefamenanu
# Processing Record 16 of Set 11 | dzhebariki-khaya
# Processing Record 17 of Set 11 | simnas
# Processing Record 18 of Set 11 | chivay
# Processing Record 19 of Set 11 | mnogovershinnyy
# Processing Record 20 of Set 11 | lalin
# Processing Record 21 of Set 11 | araouane
# Processing Record 22 of Set 11 | tual
# Processing Record 23 of Set 11 | qaqortoq
# Processing Record 24 of Set 11 | asyut
# Processing Record 25 of Set 11 | grimshaw
# Processing Record 26 of Set 11 | narsaq
# Processing Record 27 of Set 11 | santa cruz
# Processing Record 28 of Set 11 | san ramon
# Processing Record 29 of Set 11 | quixada
# Processing Record 30 of Set 11 | mjolby
# Processing Record 31 of Set 11 | genhe
# Processing Record 32 of Set 11 | yatou
# Processing Record 33 of Set 11 | marsh harbour
# Processing Record 34 of Set 11 | el prat de llobregat
# Processing Record 35 of Set 11 | karratha
# Processing Record 36 of Set 11 | socorro
# Processing Record 37 of Set 11 | potosi
# Processing Record 38 of Set 11 | el faiyum
# City not found. Skipping...
# Processing Record 39 of Set 11 | bani walid
# Processing Record 40 of Set 11 | bulawayo
# Processing Record 41 of Set 11 | taiping
# Processing Record 42 of Set 11 | abu samrah
# Processing Record 43 of Set 11 | ebolowa
# Processing Record 44 of Set 11 | kaliganj
# Processing Record 45 of Set 11 | tambopata
# Processing Record 46 of Set 11 | teeli
# Processing Record 47 of Set 11 | mabaruma
# Processing Record 48 of Set 11 | kamarion
# Processing Record 49 of Set 11 | varkkallai
# Processing Record 50 of Set 11 | mae sai
# Processing Record 1 of Set 12 | phan rang
# City not found. Skipping...
# Processing Record 2 of Set 12 | ippy
# Processing Record 3 of Set 12 | kaoma
# Processing Record 4 of Set 12 | rio grande
# Processing Record 5 of Set 12 | fomboni
# Processing Record 6 of Set 12 | half moon bay
# Processing Record 7 of Set 12 | grand forks
# Processing Record 8 of Set 12 | trimbach
# Processing Record 9 of Set 12 | san rafael
# Processing Record 10 of Set 12 | gari
# Processing Record 11 of Set 12 | quchan
# Processing Record 12 of Set 12 | silistea
# Processing Record 13 of Set 12 | ibra
# Processing Record 14 of Set 12 | puerto colombia
# Processing Record 15 of Set 12 | cobija
# Processing Record 16 of Set 12 | truth or consequences
# Processing Record 17 of Set 12 | deputatskiy
# Processing Record 18 of Set 12 | vanavara
# Processing Record 19 of Set 12 | sitka
# Processing Record 20 of Set 12 | nishihara
# Processing Record 21 of Set 12 | hualmay
# Processing Record 22 of Set 12 | sarapul
# Processing Record 23 of Set 12 | moberly
# Processing Record 24 of Set 12 | svetlaya
# Processing Record 25 of Set 12 | khor
# Processing Record 26 of Set 12 | zhanaozen
# Processing Record 27 of Set 12 | springdale
# Processing Record 28 of Set 12 | koboko
# Processing Record 29 of Set 12 | helong
# Processing Record 30 of Set 12 | namwala
# Processing Record 31 of Set 12 | ayna
# Processing Record 32 of Set 12 | talara
# Processing Record 33 of Set 12 | banda aceh
# Processing Record 34 of Set 12 | dengfeng
# Processing Record 35 of Set 12 | alyangula
# Processing Record 36 of Set 12 | bilyayivka
# Processing Record 37 of Set 12 | floro
# Processing Record 38 of Set 12 | carpentras
# Processing Record 39 of Set 12 | labuhan
# Processing Record 40 of Set 12 | prieska
# Processing Record 41 of Set 12 | muravlenko
# Processing Record 42 of Set 12 | praia da vitoria
# Processing Record 43 of Set 12 | dhidhdhoo
# Processing Record 44 of Set 12 | salinopolis
# Processing Record 45 of Set 12 | tabialan
# City not found. Skipping...
# Processing Record 46 of Set 12 | pleasanton
# Processing Record 47 of Set 12 | joao camara
# Processing Record 48 of Set 12 | yendi
# Processing Record 49 of Set 12 | kaliua
# Processing Record 50 of Set 12 | silleda
# Processing Record 1 of Set 13 | la troncal
# Processing Record 2 of Set 13 | mutsamudu
# City not found. Skipping...
# Processing Record 3 of Set 13 | pindiga
# Processing Record 4 of Set 13 | dong hoi
# Processing Record 5 of Set 13 | kpagouda
# City not found. Skipping...
# Processing Record 6 of Set 13 | mangan
# Processing Record 7 of Set 13 | mehnagar
# Processing Record 8 of Set 13 | mizdah
# Processing Record 9 of Set 13 | mbuguni
# Processing Record 10 of Set 13 | port blair
# Processing Record 11 of Set 13 | diffa
# Processing Record 12 of Set 13 | kabinda
# Processing Record 13 of Set 13 | urdoma
# Processing Record 14 of Set 13 | westport
# Processing Record 15 of Set 13 | sonari
# Processing Record 16 of Set 13 | oktyabrskoye
# Processing Record 17 of Set 13 | remanso
# Processing Record 18 of Set 13 | san quintin
# Processing Record 19 of Set 13 | buluang
# Processing Record 20 of Set 13 | muros
# Processing Record 21 of Set 13 | tevriz
# Processing Record 22 of Set 13 | tonantins
# Processing Record 23 of Set 13 | moyobamba
# Processing Record 24 of Set 13 | santa rosa
# Processing Record 25 of Set 13 | pathein
# Processing Record 26 of Set 13 | barcelos
# Processing Record 27 of Set 13 | nizhniy tsasuchey
# Processing Record 28 of Set 13 | vangaindrano
# Processing Record 29 of Set 13 | esik
# Processing Record 30 of Set 13 | saint simons
# Processing Record 31 of Set 13 | melo
# Processing Record 32 of Set 13 | perth
# Processing Record 33 of Set 13 | suntar
# Processing Record 34 of Set 13 | sorrento
# Processing Record 35 of Set 13 | cockburn harbour
# City not found. Skipping...
# Processing Record 36 of Set 13 | cocorit
# Processing Record 37 of Set 13 | horta
# Processing Record 38 of Set 13 | yarada
# Processing Record 39 of Set 13 | le moule
# Processing Record 40 of Set 13 | manakara
# Processing Record 41 of Set 13 | waterloo
# Processing Record 42 of Set 13 | bantogon
# Processing Record 43 of Set 13 | maine-soroa
# Processing Record 44 of Set 13 | baikunthpur
# Processing Record 45 of Set 13 | wajima
# Processing Record 46 of Set 13 | hami
# Processing Record 47 of Set 13 | harur
# Processing Record 48 of Set 13 | omboue
# Processing Record 49 of Set 13 | mahaicony
# City not found. Skipping...
# Processing Record 50 of Set 13 | galle
# Processing Record 1 of Set 14 | ksenyevka
# City not found. Skipping...
# Processing Record 2 of Set 14 | mama
# Processing Record 3 of Set 14 | bharatpur
# Processing Record 4 of Set 14 | elizabeth city
# Processing Record 5 of Set 14 | labuan
# Processing Record 6 of Set 14 | paamiut
# Processing Record 7 of Set 14 | changji
# Processing Record 8 of Set 14 | hillsborough
# Processing Record 9 of Set 14 | goure
# Processing Record 10 of Set 14 | trimbak
# Processing Record 11 of Set 14 | jalingo
# Processing Record 12 of Set 14 | cabinda
# Processing Record 13 of Set 14 | brewster
# Processing Record 14 of Set 14 | porto novo
# Processing Record 15 of Set 14 | mitu
# Processing Record 16 of Set 14 | chunhuhub
# Processing Record 17 of Set 14 | pacifica
# Processing Record 18 of Set 14 | rochegda
# Processing Record 19 of Set 14 | outlook
# Processing Record 20 of Set 14 | xingtai
# Processing Record 21 of Set 14 | kuche
# City not found. Skipping...
# Processing Record 22 of Set 14 | babstovo
# Processing Record 23 of Set 14 | kaohsiung
# Processing Record 24 of Set 14 | miandoab
# Processing Record 25 of Set 14 | lagoa
# Processing Record 26 of Set 14 | cap-aux-meules
# Processing Record 27 of Set 14 | iquique
# Processing Record 28 of Set 14 | primero de marzo
# Processing Record 29 of Set 14 | karasjok
# Processing Record 30 of Set 14 | eyl
# Processing Record 31 of Set 14 | sampit
# Processing Record 32 of Set 14 | darab
# Processing Record 33 of Set 14 | korolevo
# Processing Record 34 of Set 14 | forestville
# Processing Record 35 of Set 14 | tondano
# Processing Record 36 of Set 14 | hammerfest
# Processing Record 37 of Set 14 | zeven
# Processing Record 38 of Set 14 | moussoro
# Processing Record 39 of Set 14 | souillac
# Processing Record 40 of Set 14 | emba
# Processing Record 41 of Set 14 | lemay
# Processing Record 42 of Set 14 | juybar
# Processing Record 43 of Set 14 | benguela
# Processing Record 44 of Set 14 | inuvik
# Processing Record 45 of Set 14 | port-gentil
# Processing Record 46 of Set 14 | mount isa
# Processing Record 47 of Set 14 | paracatu
# Processing Record 48 of Set 14 | megion
# Processing Record 49 of Set 14 | ayagoz
# Processing Record 50 of Set 14 | caravelas
# Processing Record 1 of Set 15 | jimma
# Processing Record 2 of Set 15 | sibu
# Processing Record 3 of Set 15 | maloshuyka
# City not found. Skipping...
# Processing Record 4 of Set 15 | kargil
# Processing Record 5 of Set 15 | sarangani
# Processing Record 6 of Set 15 | livingstone
# Processing Record 7 of Set 15 | bhimunipatnam
# Processing Record 8 of Set 15 | antofagasta
# Processing Record 9 of Set 15 | bougouni
# Processing Record 10 of Set 15 | damaturu
# Processing Record 11 of Set 15 | mahibadhoo
# Processing Record 12 of Set 15 | la union
# Processing Record 13 of Set 15 | mielec
# Processing Record 14 of Set 15 | quelimane
# Processing Record 15 of Set 15 | hede
# Processing Record 16 of Set 15 | kuryk
# Processing Record 17 of Set 15 | cam pha
# City not found. Skipping...
# Processing Record 18 of Set 15 | teguldet
# Processing Record 19 of Set 15 | susehri
# Processing Record 20 of Set 15 | san juan
# Processing Record 21 of Set 15 | los llanos de aridane
# Processing Record 22 of Set 15 | eregli
# Processing Record 23 of Set 15 | rahimatpur
# Processing Record 24 of Set 15 | beni mazar
# Processing Record 25 of Set 15 | puerto escondido
# Processing Record 26 of Set 15 | chaman
# Processing Record 27 of Set 15 | komsomolskiy
# Processing Record 28 of Set 15 | oyama
# Processing Record 29 of Set 15 | denpasar
# Processing Record 30 of Set 15 | banepa
# Processing Record 31 of Set 15 | ponferrada
# Processing Record 32 of Set 15 | maribong
# Processing Record 33 of Set 15 | semenyih
# Processing Record 34 of Set 15 | arani
# Processing Record 35 of Set 15 | kirovskiy
# Processing Record 36 of Set 15 | ponta delgada
# Processing Record 37 of Set 15 | gravdal
# Processing Record 38 of Set 15 | buta
# Processing Record 39 of Set 15 | paramonga
# Processing Record 40 of Set 15 | fukue
# Processing Record 41 of Set 15 | whitehorse
# Processing Record 42 of Set 15 | samagaltay
# Processing Record 43 of Set 15 | paz de ariporo
# City not found. Skipping...
# Processing Record 44 of Set 15 | felidhoo
# City not found. Skipping...
# Processing Record 45 of Set 15 | urdzhar
# City not found. Skipping...
# Processing Record 46 of Set 15 | viedma
# Processing Record 47 of Set 15 | bulaevo
# Processing Record 48 of Set 15 | maun
# Processing Record 49 of Set 15 | kachiry
# Processing Record 50 of Set 15 | kismayo
# Processing Record 1 of Set 16 | ginir
# Processing Record 2 of Set 16 | abha
# Processing Record 3 of Set 16 | elko
# Processing Record 4 of Set 16 | la ronge
# Processing Record 5 of Set 16 | wukari
# Processing Record 6 of Set 16 | rorvik
# Processing Record 7 of Set 16 | tres palos
# Processing Record 8 of Set 16 | magistralnyy
# Processing Record 9 of Set 16 | miri
# Processing Record 10 of Set 16 | banyo
# Processing Record 11 of Set 16 | ulaanbaatar
# Processing Record 12 of Set 16 | altagracia de orituco
# Processing Record 13 of Set 16 | camabatela
# Processing Record 14 of Set 16 | tawkar
# City not found. Skipping...
# Processing Record 15 of Set 16 | ushtobe
# Processing Record 16 of Set 16 | kralendijk
# Processing Record 17 of Set 16 | leeuwarden
# Processing Record 18 of Set 16 | dekoa
# City not found. Skipping...
# Processing Record 19 of Set 16 | goderich
# Processing Record 20 of Set 16 | jos
# Processing Record 21 of Set 16 | ducheng
# Processing Record 22 of Set 16 | praya
# Processing Record 23 of Set 16 | chegdomyn
# Processing Record 24 of Set 16 | oktyabrskiy
# Processing Record 25 of Set 16 | putina
# Processing Record 26 of Set 16 | sunnyside
# Processing Record 27 of Set 16 | apc
# Processing Record 28 of Set 16 | grand-lahou
# Processing Record 29 of Set 16 | kalianget
# Processing Record 30 of Set 16 | olinda
# Processing Record 31 of Set 16 | gunjur
# Processing Record 32 of Set 16 | ambon
# Processing Record 33 of Set 16 | coquimbo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Ushuaia      AR -54.8000  -68.3000     46.02        70          20
# 1   New Norfolk      AU -42.7826  147.0587     45.90        89           3
# 2       Tha Mai      TH  12.6214  102.0048     82.06        85          68
# 3        Shingu      JP  33.7333  135.9833     62.15        89         100
# 4       Garmsar      IR  35.2182   52.3409     73.49        22          15
# 5      Hermanus      ZA -34.4187   19.2345     65.80        72          90
# 6         Khash      IR  28.2211   61.2158     75.97        22           0
# 7        Lucapa      AO  -8.4192   20.7447     74.91        58          95
# 8  Marsa Matruh      EG  31.3525   27.2453     65.30        75           7
# 9      Yuncheng      CN  35.0231  110.9928     62.49        60         100
#
#    Wind Speed Current Description
# 0        4.61          few clouds
# 1        3.49           clear sky
# 2        2.35       broken clouds
# 3        7.81          light rain
# 4        7.90          few clouds
# 5       17.81     overcast clouds
# 6        5.37           clear sky
# 7        3.67     overcast clouds
# 8        4.27           clear sky
# 9        2.64     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Data/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
